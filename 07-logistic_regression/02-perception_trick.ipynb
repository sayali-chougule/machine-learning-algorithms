# %% [markdown]
# ## Perceptron Trick

# %%
from sklearn.datasets import make_classification
import numpy as np
X, y = make_classification(n_samples=100, n_features=2, n_informative=1, n_redundant=0, n_classes=2, n_clusters_per_class=1, random_state=41, hypercube=False, class_sep=10)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,6))
plt.scatter(X[:,0], X[:,1], c=y, cmap='winter', s=100)

# %%
def perceptron(X,y):
    X = np.insert(X,0,1,axis=1)
    weights = np.ones(X.shape[1])
    lr = 0.1

    for i in range(1000):
        j = np.random.randint(0,100)
        y_hat = step(np.dot(X[j], weights))
        weights = weights + lr*(y[j]-y_hat)*X[j]

    return weights[0], weights[1:]

# %%
def step(z):
    return 1 if z>0 else 0

# %%
intercept_, coef_ = perceptron(X, y)

# %%
print(coef_)
print(intercept_)
# Out:
# [1.27064853 0.05801522]
# 1.0

# %%
m = -(coef_[0]/coef_[1])
b = -(intercept_/coef_[1])

# %%
x_input = np.linspace(-3, 3, 100)
y_input = m*x_input + b

# %%
plt.figure(figsize=(10,6))
plt.plot(x_input, y_input, color='red', linewidth=3)
plt.scatter(X[:, 0], X[:, 1], c=y, cmap='winter', s=100)
plt.ylim(-3, 2)
# Out:
# (-3.0, 2.0)

# %%
def perceptron(X, y):

    m = []
    b = []

    X = np.insert(X,0,1,axis=1)
    weights = np.ones(X.shape[1])
    lr = 0.1


    for i in range(200):
        j = np.random.randint(0,100)
        y_hat = step(np.dot(X[j], weights))
        weights = weights + lr*(y[j]-y_hat)*X[j]

        m.append(-(weights[1]/weights[2]))
        b.append(-(weights[0]/weights[2]))

    return m,b

# %%
m, b = perceptron(X, y)

# %%
# %matplotlib notebook
from matplotlib.animation import FuncAnimation
import matplotlib.animation as animation

# %%
fig, ax = plt.subplots(figsize=(9,5))

x_i = np.arange(-3, 3, 0.1)

# Initial line
line, = ax.plot(x_i, x_i*m[0] + b[0], 'r-', linewidth=2)

# Scatter plot
ax.scatter(X[:,0], X[:,1], c=y, cmap='winter', s=100)

plt.ylim(-3, 3)

def update(i):
    y_i = x_i * m[i] + b[i]
    line.set_ydata(y_i)
    
    ax.set_title(f"Epoch {i+1}")   # better than xlabel
    
    return line,

# IMPORTANT: frames should match length of m/b
anim = FuncAnimation(
    fig,
    update,
    frames=len(m),
    interval=100,
    repeat=True
)

plt.show()
anim.save("training.gif", writer='pillow')
# Out:
# <div id='7a36e204-6387-4415-8523-94e541091cb9'></div>

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
lor = LogisticRegression()
lor.fit(X,y)
# Out:
# LogisticRegression()

# %%
m = -(lor.coef_[0][0]/lor.coef_[0][1])
b = -(lor.intercept_/lor.coef_[0][1])

# %%
x_input1 = np.linspace(-3,3,100)
y_input1 = m*x_input + b

# %%
import matplotlib.pyplot as pl

# %%
pl.figure(figsize=(10,6))
pl.plot(x_input,y_input,color='red',linewidth=3)
pl.plot(x_input1,y_input1,color='black',linewidth=3)
pl.scatter(X[:,0],X[:,1],c=y,cmap='winter',s=100)
pl.ylim(-3,2)
# pl.show()
# Out:
# <div id='e9ab671f-7998-4021-b831-f5fd6c3e95a5'></div>
# (-3.0, 2.0)
