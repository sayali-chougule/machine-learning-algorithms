# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('02-ushape.csv')

# %%
df.head()
# Out:
#    3.159499363321345566e-02  9.869877579082642072e-01  \
# 0                  2.115098                 -0.046244
# 1                  0.882490                 -0.075756
# 2                 -0.055144                 -0.037332
# 3                  0.829545                 -0.539321
# 4                  2.112857                  0.662084
#
#    0.000000000000000000e+00
# 0                       1.0
# 1                       0.0
# 2                       1.0
# 3                       1.0
# 4                       1.0

# %%
df.columns
# Out:
# Index(['3.159499363321345566e-02', '9.869877579082642072e-01',
#        '0.000000000000000000e+00'],
#       dtype='object')

# %%
df.rename(columns={"3.159499363321345566e-02": "X", "9.869877579082642072e-01": "Y", "0.000000000000000000e+00":"class"}, inplace=True)

# %%
df.head()
# Out:
#           X         Y  class
# 0  2.115098 -0.046244    1.0
# 1  0.882490 -0.075756    0.0
# 2 -0.055144 -0.037332    1.0
# 3  0.829545 -0.539321    1.0
# 4  2.112857  0.662084    1.0

# %%
X = df.iloc[:, :2]
y = df.iloc[:, -1]

# %%
plt.scatter(X.iloc[:,0], X.iloc[:,1], c=y)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lgr = LogisticRegression()

# %%
lgr.fit(X,y)
# Out:
# LogisticRegression()

# %%
# Noraml logistic regression
from mlxtend.plotting import plot_decision_regions

plot_decision_regions(X.values, y.astype('int').values, lgr, legend=2)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# <Axes: >

# %%
from sklearn.model_selection import cross_val_score
np.mean(cross_val_score(lgr, X, y, scoring='accuracy', cv=10))
# Out:
# np.float64(0.8300000000000001)

# %% [markdown]
# How to improve accuracy

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree=3, include_bias=False)
X_trf = poly.fit_transform(X)

# %%
lgr1 = LogisticRegression()
np.mean(cross_val_score(lgr1, X_trf, y, scoring='accuracy', cv=10))
# Out:
# np.float64(0.9099999999999999)

# %%
def plot_decision_boundary(X,y,degree=1):
    
    poly = PolynomialFeatures(degree=degree)
    X_trf = poly.fit_transform(X)
    
    lgr = LogisticRegression()
    lgr.fit(X_trf,y)
    
    accuracy = np.mean(cross_val_score(lgr,X_trf,y,scoring='accuracy',cv=10))
    
    a=np.arange(start=X[:,0].min()-1, stop=X[:,0].max()+1, step=0.01)
    b=np.arange(start=X[:,1].min()-1, stop=X[:,1].max()+1, step=0.01)


    XX,YY=np.meshgrid(a,b)
    
    input_array=np.array([XX.ravel(),YY.ravel()]).T

    labels=lgr.predict(poly.transform(input_array))
    
    plt.contourf(XX,YY,labels.reshape(XX.shape),alpha=0.5)
    plt.scatter(X[:,0],X[:,1], c=y)
    plt.title('Degree = {}, accuracy is {}'.format(degree,np.round(accuracy,4)))

# %%
plot_decision_boundary(X.values,y.values)

# %%
plot_decision_boundary(X.values,y.values, degree=2)

# %%
plot_decision_boundary(X.values,y.values, degree=3)

# %%
plot_decision_boundary(X.values,y.values, degree=4)

# %%
plot_decision_boundary(X.values,y.values, degree=5)

# %%
plot_decision_boundary(X.values,y.values, degree=6)

# %%
plot_decision_boundary(X.values,y.values, degree=25)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:406: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:406: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
# ...
